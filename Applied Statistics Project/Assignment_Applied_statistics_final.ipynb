# %%
# Importing Necessary Libraries to perform EDA on the dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("Necessary Libraries imported")
# Out:
# Necessary Libraries imported

# %%
data  = pd.read_csv('insurance.csv') # Import the dataset named 'insurance.csv'
data.head()  # view the first 5 rows of the data
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# 3a Shape of the data
data.shape
# Out:
# (1338, 7)

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
#3b Data type of each attribute
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
data.dtypes.value_counts()
# Out:
# object     3
# int64      2
# float64    2
# dtype: int64

# %%
#3c Checking the presence of missing values
def missing_check(df):
    total = df.isnull().sum().sort_values(ascending=False)   # total number of null values
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)  # percentage of values that are null
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])  # putting the above two together
    return missing_data # return the dataframe
missing_check(data)
# Out:
#           Total  Percent
# charges       0      0.0
# region        0      0.0
# smoker        0      0.0
# children      0      0.0
# bmi           0      0.0
# sex           0      0.0
# age           0      0.0

# %%
#3d Five point summary of numerical attributes
#the five-point summary consists of the following:
#The minimum – this is the smallest value in our data set.
#The first quartile – this number is denoted Q1 and 25% of our data falls below the first quartile.
#The median – this is the midway point of the data. 50% of all data falls below the median.
#The third quartile – this number is denoted Q3 and 75% of our data falls below the third quartile.
#The maximum – this is the largest value in our data set.
data[['age','bmi','children','charges']].describe() #descriptive stats of numeric columns
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.boxplot(x=data['bmi'])   # box plot

# %%
sns.boxplot(x=data['age'])   # box plot

# %%
sns.boxplot(x=data['charges'])   # box plot

# %%
#3e Distribution of ‘bmi’, ‘age’ and ‘charges’ columns.
# The following code plots a histrogram using the matplotlib package.
# The bins argument creates class intervals. In this case we are creating 50 such intervals
mean=Data['bmi'].mean()
median=Data['bmi'].median()
mode=Data['bmi'].mode()
print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])


plt.figure(figsize=(15,10)) # set the figure size
plt.hist(data.bmi, bins=50) #Plot the histogram
plt.axvline(data.bmi.mean(), color='m', linewidth=1 ,label='Mean')# Draw lines on the plot for mean median and the mode
plt.axvline(data.bmi.median(), color='b', linestyle='dashed', linewidth=1,label='Median')
plt.axvline(data.bmi.mode()[0], color='g', linestyle='dashed', linewidth=1,label='Mode')

plt.xlabel('bmi')   # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  30.663396860986538
# Median:  30.4
# Mode:  32.3

# %%
sns.distplot(data.bmi) # plots a frequency polygon superimposed on a histogram using the seaborn package.
# seaborn automatically creates class intervals. The number of bins can also be manually set.

# %%
sns.violinplot(data.bmi) # plots a violin plt using the seaborn package.

# %%
#3e Distribution of ‘bmi’, ‘age’ and ‘charges’ columns.
# The following code plots a histrogram using the matplotlib package.
# The bins argument creates class intervals. In this case we are creating 50 such intervals
mean=Data['age'].mean()
median=Data['age'].median()
mode=Data['age'].mode()
print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(15,10)) # set the figure size
plt.hist(data.age, bins=50)
plt.axvline(data.age.mean(), color='m', linewidth=1, label='Mean')
plt.axvline(data.age.median(), color='b', linestyle='dashed', linewidth=1, label='Median')
plt.axvline(data.age.mode()[0], color='g', linestyle='dashed', linewidth=1, label='Mode')

plt.xlabel('age')   # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  39.20702541106129
# Median:  39.0
# Mode:  18

# %%
sns.distplot(data.age) # plots a frequency polygon superimposed on a histogram using the seaborn package.
# seaborn automatically creates class intervals. The number of bins can also be manually set.

# %%
sns.violinplot(data.age) # plots a violin plt using the seaborn package.

# %%
#3e Distribution of ‘bmi’, ‘age’ and ‘charges’ columns.
# The following code plots a histrogram using the matplotlib package.
# The bins argument creates class intervals. In this case we are creating 50 such intervals
mean=Data['charges'].mean()
median=Data['charges'].median()
mode=Data['charges'].mode()
print('Mean: ',mean,'\nMedian: ',median,'\nMode: ',mode[0])

plt.figure(figsize=(15,10)) # set the figure size
plt.hist(data.charges, bins=50)
plt.axvline(data.charges.mean(), color='m', linewidth=1, label='Mean')
plt.axvline(data.charges.median(), color='b', linestyle='dashed', linewidth=1, label='Median')
plt.axvline(data.charges.mode()[0], color='g', linestyle='dashed', linewidth=1, label='Mode')

plt.xlabel('charges')   # label the x-axis
plt.ylabel('Frequency')   # label the y-axis
plt.legend()              # Plot the legend
plt.show()
# Out:
# Mean:  13270.422265141257
# Median:  9382.033
# Mode:  1639.5631

# %%
sns.distplot(data.charges) # plots a frequency polygon superimposed on a histogram using the seaborn package.
# seaborn automatically creates class intervals. The number of bins can also be manually set.

# %%
sns.violinplot(data.charges) # plots a violin plt using the seaborn package.

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %%
#3f Measure of skewness of ‘bmi’, ‘age’ and ‘charges’ columns
#skewness -Pandas dataframe.skew() function return unbiased skew over requested axis Normalized by N-1. 
#Skewness is a measure of the asymmetry of the probability distribution of a real-valued random variable about its mean.
# skewness along the index axis 
data.skew(axis = 0, skipna = True) 
#Positively skewed: Most frequent values are low and tail is towards high values.
#Negatively skewed: Most frequent values are high and tail is towards low values.
# Out:
# age         0.055673
# bmi         0.284047
# children    0.938380
# charges     1.515880
# dtype: float64

# %% [markdown]
# In this case,charges and more positively skewed that age and bmi and hence most frequent values of charges are low and the tail is towards high values

# %%
#3g Checking the presence of outliers in ‘bmi’, ‘age’ and ‘charges columns

# %%
#3g Checking the presence of outliers in ‘bmi’, ‘age’ and ‘charges columns
# we can do thisusing box plot, the data points lying outside the whiskers are outliers as the whiskers extend to 1.5 times the interquartile range
sns.boxplot(x=data['bmi'])   # box plot
# Some Outliers to the right side of Q3

# %%
#3g Checking the presence of outliers in ‘bmi’, ‘age’ and ‘charges columns
# we can do thisusing box plot, the data points lying outside the whiskers are outliers as the whiskers extend to 1.5 times the interquartile range
sns.boxplot(x=data['age'])   # box plot
# No Outliers

# %%
#3g Checking the presence of outliers in ‘bmi’, ‘age’ and ‘charges columns
# we can do thisusing box plot, the data points lying outside the whiskers are outliers as the whiskers extend to 1.5 times the interquartile range
sns.boxplot(x=data['charges'])   # box plot
# Many Outliers to the right side of Q3

# %%
#3h h. Distribution of categorical columns (include children) 
sns.catplot(x="sex", y="charges", data=data)

# %%
#3h h. Distribution of categorical columns (include children) 
#check for null values
data.isnull().sum()
sns.catplot(x="sex", kind="count", palette="ch:.25", data=data)

# %%
#3h h. Distribution of categorical columns (include children) 
#check for null values
data.isnull().sum()
sns.catplot(x="region", kind="count", palette="ch:.25", data=data)

# %%
#3h h. Distribution of categorical columns (include children) 
#check for null values
data.isnull().sum()
sns.catplot(x="children", kind="count", palette="ch:.25", data=data)

# %%
#3h h. Distribution of categorical columns (include children) 
#check for null values
data.isnull().sum()
sns.catplot(x="smoker", kind="count", palette="ch:.25", data=data)

# %%
#3i pair plot for all attributes
sns.pairplot(data, kind="reg")  # plots scatter plots for every pair of attributes and histograms along the diagonal
plt.show()

# %%
#4a Do charges of people who smoke differ significantly from the people who don't?
sns.catplot(x="smoker", y="charges", data=data)
plt.figure(figsize=(10,5))  # setting the figure size
ax = sns.barplot(x="smoker", y="charges", data=data, palette='muted')  # barplot

# %%
#4a Do charges of people who smoke differ significantly from the people who don't?
# scatter plot between smoker and charges 
plt.scatter(data['smoker'], data['charges']) 
plt.show()

# %%
#4a Do charges of people who smoke differ significantly from the people who don't?
# scatter plot between smoker and charges 
sns.boxplot(x="smoker", y="charges", data=data)
plt.show()

# %%
#4b. Does bmi of males differ significantly from that of females? (7 marks)
sns.boxplot(x="sex", y="bmi", data=data)

# %%
#4c Is the proportion of smokers significantly different in different genders
import pandas as pd
pd.crosstab(data.smoker, data.sex, margins=True, margins_name="Total")
# Out:
# sex     female  male  Total
# smoker
# no         547   517   1064
# yes        115   159    274
# Total      662   676   1338

# %%
#4c Is the proportion of smokers significantly different in different genders
import pandas as pd
data.pivot_table(index='smoker', columns='sex', aggfunc={'sex':len}, fill_value=0)
# Out:
#           sex
# sex    female male
# smoker
# no        547  517
# yes       115  159

# %%
male_proportion=159/676
female_proportion=115/662
print("Proportion of male smokers vs non smokers :" , male_proportion)
print("Proportion of female smokers vs non smokers :" , female_proportion)

# Not significant different
# Out:
# Proportion of male smokers vs non smokers : 0.23520710059171598
# Proportion of female smokers vs non smokers : 0.17371601208459214

# %%
#4d Is the distribution of bmi across women with no children, one child and two children, the same
plt.figure(figsize=(15,5))

sns.catplot(x="children", y="bmi",  kind="point", data=data[data['sex']=="female"]);

# %%
#4d Is the distribution of bmi across women with no children, one child and two children, the same
data_female= data[data['sex']=="female"]
sns.boxplot(x="children", y="bmi", data=data[data['sex']=="female"])
plt.show()
